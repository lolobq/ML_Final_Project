# %% [markdown]
# # **Adding HIGHEST_NIBRS_DESCRIPTION column back to df6.csv**

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler, LabelEncoder
df = pd.read_csv("C:/Users/aidan_000/Desktop/UNCC/ML Project/Datasets/df6.csv", low_memory=False)

df = df.rename(columns={'HIGHEST_NIBRS_DESCRIPTION': 'HIGHEST_NIBRS_CODE'})

# Mapping of offense codes to descriptions
offense_mapping = {
    0: "Other Unlisted Non-Criminal",
    1: "Theft From Motor Vehicle",
    2: "Damage/Vandalism Of Property",
    3: "Theft From Building",
    4: "All Other Offenses",
    5: "All Other Thefts",
    6: "Motor Vehicle Theft",
    7: "Intimidation",
    8: "Simple Assault",
    9: "Aggravated Assault",
    10: "Burglary/B&E",
    11: "Theft of Motor Vehicle Parts from Vehicle",
    12: "Counterfeiting/Forgery",
    13: "Missing Person",
    14: "Drug/Narcotic Violations",
    15: "Shoplifting",
    16: "Vehicle Recovery",
    17: "Credit Card/Teller Fraud",
    18: "Robbery",
    19: "Forcible Rape",
    20: "Identity Theft",
    21: "Stolen Property Offenses",
    22: "Impersonation",
    23: "Sudden/Natural Death Investigation",
    24: "Pocket-Picking",
    25: "Weapon Law Violations",
    26: "Arson",
    27: "Curfew/Loitering/Vagrancy Violations",
    28: "Negligent Manslaughter",
    29: "Murder",
    30: "Affray",
    31: "Purse-Snatching",
    32: "False Pretenses/Swindle",
    33: "Drug Equipment Violations",
    34: "Family Offenses; Nonviolent",
    35: "Overdose",
    36: "Public Accident",
    37: "Trespass Of Real Property",
    38: "Driving Under The Influence",
    39: "Kidnapping",
    40: "Suicide",
    41: "Embezzlement",
    42: "Pornography/Obscene Material",
    43: "Forcible Fondling",
    44: "Indecent Exposure",
    45: "Hacking/Computer Invasion",
    46: "Forcible Sodomy",
    47: "Extortion/Blackmail",
    48: "Fire (Accidental/Non-Arson)",
    49: "Disorderly Conduct",
    50: "Liquor Law Violations",
    51: "Theft From Coin-Operated Machine Or Device",
    52: "Incest",
    53: "Statutory Rape",
    54: "Worthless Check: Felony (over $2000)",
    55: "Peeping Tom",
    56: "Wire Fraud",
    57: "Animal Cruelty",
    58: "Assisting Gambling",
    59: "Justifiable Homicide",
    60: "Prostitution",
    61: "Involuntary Servitude",
    62: "Commercial Sex Acts",
    63: "Sexual Assault With Object",
    64: "Assisting Prostitution",
    65: "Gambling Equipment Violations",
    66: "Betting/Wagering",
    67: "Dog Bite/Animal Control Incident",
    68: "Gas Leak",
    69: "Welfare Fraud",
    70: "Purchasing Prostitution",
    71: "Bribery",
}

# Function to map offense codes to descriptions
def map_code_to_offense(offense_code, offense_mapping):
    return offense_mapping.get(offense_code, "Unknown")

# Apply the mapping function to create a new column
df['HIGHEST_NIBRS_DESCRIPTION'] = df['HIGHEST_NIBRS_CODE'].apply(lambda x: map_code_to_offense(x, offense_mapping))

# Define the desired order of columns
desiredOrder = ['ZIP', 'LATITUDE_PUBLIC', 'LONGITUDE_PUBLIC', 'Year', 'Month', 'Day', 'DayOfWeek', 'CMPD_PATROL_DIVISION', 'LOCATION_TYPE_DESCRIPTION', 'PLACE_TYPE_DESCRIPTION', 'PLACE_DETAIL_DESCRIPTION', 'HIGHEST_NIBRS_CODE', 'HIGHEST_NIBRS_DESCRIPTION','People', 'PctHighSchool', 'PctNonWhite', 'Pct65_', 'PctHH_Poverty', 'PctHome_Ownership', 'HighSchool', 'NonWhite', 'F65_', 'Poverty', 'Home_Ownership', 'Score', 'VulnerableBinary', 'Violent-Crime']
df = df[desiredOrder]


# Create a DataFrame of unique values and their counts
unique_values_counts = df.groupby(['HIGHEST_NIBRS_DESCRIPTION', 'HIGHEST_NIBRS_CODE']).size().reset_index(name='Count')

# Sort the DataFrame by 'HIGHEST_NIBRS_DESCRIPTION' and 'Count' in descending order
unique_values_counts = unique_values_counts.sort_values(by=['Count'], ascending=False)

# Print the sorted DataFrame
print("Description, Code, and Count (Sorted by Count in Descending Order):")
print(unique_values_counts)
# Out:
# Description, Code, and Count (Sorted by Count in Descending Order):
#                     HIGHEST_NIBRS_DESCRIPTION  HIGHEST_NIBRS_CODE  Count
# 41                   Theft From Motor Vehicle                   1  44675
# 1                            All Other Thefts                   5  38155
# 37                             Simple Assault                   8  29240
# 36                                Shoplifting                  15  26019
# 9                Damage/Vandalism Of Property                   2  24422
# 6                                Burglary/B&E                  10  18938
# 26                        Motor Vehicle Theft                   6  14237
# 23                               Intimidation                   7  12212
# 12                   Drug/Narcotic Violations                  14  10805
# 0                          Aggravated Assault                   9  10337
# 42  Theft of Motor Vehicle Parts from Vehicle                  11   9057
# 15                    False Pretenses/Swindle                  32   7067
# 34                                    Robbery                  18   6260
# 40                        Theft From Building                   3   4153
# 7                      Counterfeiting/Forgery                  12   2418
# 39                   Stolen Property Offenses                  21   2359
# 43                      Weapon Law Violations                  25   2311
# 17                          Forcible Fondling                  43   1810
# 11                  Drug Equipment Violations                  33   1703
# 21                              Impersonation                  22   1694
# 10                Driving Under The Influence                  38   1604
# 13                               Embezzlement                  41   1479
# 18                              Forcible Rape                  19    779
# 31               Pornography/Obscene Material                  42    752
# 30                             Pocket-Picking                  24    737
# 2                                       Arson                  26    644
# 25                                 Kidnapping                  39    614
# 14                        Extortion/Blackmail                  47    603
# 33                            Purse-Snatching                  31    496
# 27                                     Murder                  29    336
# 16                Family Offenses; Nonviolent                  34    242
# 19                            Forcible Sodomy                  46    165
# 45                                 Wire Fraud                  56    146
# 38                             Statutory Rape                  53    132
# 29                                Peeping Tom                  55    116
# 8        Curfew/Loitering/Vagrancy Violations                  27     73
# 35                 Sexual Assault With Object                  63     44
# 24                       Justifiable Homicide                  59     39
# 32                               Prostitution                  60     35
# 28                     Negligent Manslaughter                  28     15
# 22                                     Incest                  52     11
# 20              Gambling Equipment Violations                  65      9
# 4                            Betting/Wagering                  66      3
# 3                          Assisting Gambling                  58      3
# 5                                     Bribery                  71      1
# 44                              Welfare Fraud                  69      1

# %% [markdown]
# # **Class Reduction based on Type of Offense in df7.csv**

# %%
df = pd.read_csv("C:/Users/aidan_000/Desktop/UNCC/ML Project/Datasets/df7.csv", low_memory=False)

## Offenses to be removed from the DataFrame
values_to_remove = ['Extortion/Blackmail', 'Justifiable Homicide', 'Family Offenses; Nonviolent', 'Curfew/Loitering/Vagrancy Violations', 'Weapon Law Violations']

# Remove rows where 'HIGHEST_NIBRS_DESCRIPTION' is in values_to_remove
df = df[~df['HIGHEST_NIBRS_DESCRIPTION'].isin(values_to_remove)]

# Mapping of crimes to their types
crime_mapping = {
    'Sexual Offenses':   ['Forcible Fondling', 'Forcible Rape', 'Forcible Sodomy', 'Incest', 'Peeping Tom', 'Pornography/Obscene Material', 'Prostitution', 'Sexual Assault With Object', 'Statutory Rape'],
    'Money Offenses':    ['Assisting Gambling', 'Betting/Wagering', 'Bribery', 'Embezzlement', 'Assisting Prostitution', 'Gambling Equipment Violations', 'False Pretenses/Swindle'],
    'Drug Offenses':     ['Driving Under The Influence', 'Drug/Narcotic Violations', 'Drug Equipment Violations'],
    'Assault':           ['Aggravated Assault', 'Intimidation', 'Kidnapping', 'Murder', 'Negligent Manslaughter', 'Simple Assault'],
    'Property Offenses': ['Arson', 'Damage/Vandalism Of Property'],
    'Falsification':     ['Counterfeiting/Forgery', 'Impersonation', 'Welfare Fraud', 'Wire Fraud'],
    'Thefts':            ['Pocket-Picking', 'Robbery', 'Shoplifting', 'Stolen Property Offenses', 'Burglary/B&E', 'All Other Thefts', 'Theft From Building', 'Purse-Snatching'],
    'Vehicle Thefts':    ['Motor Vehicle Theft', 'Theft From Motor Vehicle', 'Theft of Motor Vehicle Parts from Vehicle']
}

# Create a new column 'CRIME_TYPE' based on 'HIGHEST_NIBRS_DESCRIPTION'
df['CRIME_TYPE'] = df['HIGHEST_NIBRS_DESCRIPTION'].apply(lambda x: next((key for key, value in crime_mapping.items() if x in value), x))

# Define a mapping for integer values representing crime types
integer_mapping = {
    'Assault':           0,
    'Thefts':            1,
    'Vehicle Thefts':    2, 
    'Property Offenses': 3,
    'Sexual Offenses':   4,
    'Money Offenses':    5,
    'Drug Offenses':     6,
    'Falsification':     7
}

# Map the integer values to the 'CRIME_TYPE' column to create 'CRIME_TYPE_MAP'
df['CRIME_TYPE_MAP'] = df['CRIME_TYPE'].map(integer_mapping)

# Define the desired order of columns
desiredOrder = ['ZIP', 'LATITUDE_PUBLIC', 'LONGITUDE_PUBLIC', 'Year', 'Month', 'Day', 'DayOfWeek', 'CMPD_PATROL_DIVISION', 'LOCATION_TYPE_DESCRIPTION', 'PLACE_TYPE_DESCRIPTION', 'PLACE_DETAIL_DESCRIPTION', 'HIGHEST_NIBRS_CODE', 'HIGHEST_NIBRS_DESCRIPTION', 'CRIME_TYPE', 'CRIME_TYPE_MAP' ,'People', 'PctHighSchool', 'PctNonWhite', 'Pct65_', 'PctHH_Poverty', 'PctHome_Ownership', 'HighSchool', 'NonWhite', 'F65_', 'Poverty', 'Home_Ownership', 'Score', 'VulnerableBinary', 'Violent-Crime']
df = df[desiredOrder]

# Create a DataFrame of unique values for 'HIGHEST_NIBRS_DESCRIPTION', 'CRIME_TYPE', and 'CRIME_TYPE_MAP'
unique_values_df = df[['HIGHEST_NIBRS_DESCRIPTION', 'CRIME_TYPE', 'CRIME_TYPE_MAP']].drop_duplicates()

# Sort the DataFrame by 'CRIME_TYPE_MAP'
unique_values_df = unique_values_df.sort_values(by='CRIME_TYPE_MAP')

# Print the original and grouped crime types along with their encoded values
print("Original and Grouped Crime Types:")
print(unique_values_df)

# Save the Enumoration Map with desired columns to a CSV file
#unique_values_df.to_csv('CRIME_TYPE.csv', index=False)
# Out:
# Original and Grouped Crime Types:
#                         HIGHEST_NIBRS_DESCRIPTION         CRIME_TYPE  \
# 294                                    Kidnapping            Assault
# 2689                       Negligent Manslaughter            Assault
# 4                                    Intimidation            Assault
# 5                                  Simple Assault            Assault
# 9                              Aggravated Assault            Assault
# 1537                                       Murder            Assault
# 187                           Theft From Building             Thefts
# 168                               Purse-Snatching             Thefts
# 65                                 Pocket-Picking             Thefts
# 43                       Stolen Property Offenses             Thefts
# 34                                   Burglary/B&E             Thefts
# 32                                        Robbery             Thefts
# 19                                    Shoplifting             Thefts
# 2                                All Other Thefts             Thefts
# 23      Theft of Motor Vehicle Parts from Vehicle     Vehicle Thefts
# 3                             Motor Vehicle Theft     Vehicle Thefts
# 0                        Theft From Motor Vehicle     Vehicle Thefts
# 1                    Damage/Vandalism Of Property  Property Offenses
# 212                                         Arson  Property Offenses
# 1636                                       Incest    Sexual Offenses
# 1730                            Forcible Fondling    Sexual Offenses
# 20327                  Sexual Assault With Object    Sexual Offenses
# 7227                                  Peeping Tom    Sexual Offenses
# 12585                                Prostitution    Sexual Offenses
# 1859                               Statutory Rape    Sexual Offenses
# 785                               Forcible Sodomy    Sexual Offenses
# 229                                 Forcible Rape    Sexual Offenses
# 425                  Pornography/Obscene Material    Sexual Offenses
# 366                                  Embezzlement     Money Offenses
# 184                       False Pretenses/Swindle     Money Offenses
# 7410                           Assisting Gambling     Money Offenses
# 24976               Gambling Equipment Violations     Money Offenses
# 31194                            Betting/Wagering     Money Offenses
# 244703                                    Bribery     Money Offenses
# 186                     Drug Equipment Violations      Drug Offenses
# 157                      Drug/Narcotic Violations      Drug Offenses
# 675                   Driving Under The Influence      Drug Offenses
# 374                        Counterfeiting/Forgery      Falsification
# 217163                              Welfare Fraud      Falsification
# 3439                                   Wire Fraud      Falsification
# 52                                  Impersonation      Falsification
#
#         CRIME_TYPE_MAP
# 294                  0
# 2689                 0
# 4                    0
# 5                    0
# 9                    0
# 1537                 0
# 187                  1
# 168                  1
# 65                   1
# 43                   1
# 34                   1
# 32                   1
# 19                   1
# 2                    1
# 23                   2
# 3                    2
# 0                    2
# 1                    3
# 212                  3
# 1636                 4
# 1730                 4
# 20327                4
# 7227                 4
# 12585                4
# 1859                 4
# 785                  4
# 229                  4
# 425                  4
# 366                  5
# 184                  5
# 7410                 5
# 24976                5
# 31194                5
# 244703               5
# 186                  6
# 157                  6
# 675                  6
# 374                  7
# 217163               7
# 3439                 7
# 52                   7
